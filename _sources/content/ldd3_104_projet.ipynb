# %% [markdown]
# # PROJET - Graphes orientés et pondérés
#
# page web ressources : https://bruno2nis.github.io/ldd3_104_info/content/4_projet.html

# %% [markdown]
# ## Définition de la classe Graphe
#
# La structure de base de la classe `Graph` est ébauchée dans la cellule suivante

# %%
class Graph():
    """Graph orienté et pondéré."""
    def __init__(self):
        self.nom = "graphe_vide"
    def __str__(self):
        return self.nom
    def __repr__(self):
        return self.nom
    def changer_nom(self):
        pass
    def ajouter_sommet(self):
        pass
    def ajouter_arc(self):
        pass
    def initialiser_avec_dict(self):
        pass
    def initialiser_avec_fichier(self):
        pass
    def sauver_dans_fichier(self):
        pass
    def dijstra():
        pass
    def rapport_textuel(self):
        pass
    def rapport_html(self):
        pass

# %% [markdown]
# ## Les attendus de la séance 1
#
# 1. À partir du diagramme de classe UML proposé, structurer les données internes d'un objet `Graphe` pour qu'il puisse accueillir des arcs, des sommets et les relations qui les lient (les arcs et les sommets pourront être définis dans des classes d'objets propres, mais sans obligation)
#
# 2. Coder les méthodes  `changer_nom()`, `ajouter_sommet()`, `ajouter_arc()`, `__str__()` et  `__repr__()` pour obtenir le comportement suivant
#
# ```python
# g = Graphe()
# str(g)  # donne "<Graphe: graphe_vide, 0 sommets, 0 arcs>"
# g.changer_nom("mon_graphe")
# str(g)  # donne "<Graphe: mon_graphe, 0 sommets, 0 arcs>"
# g.ajouter_sommet("A")
# g.ajouter_sommet("B")
# g.ajouter_arc("A", "B", 5)
# str(g)  # donne "<Graphe: mon_graphe, 2 sommets, 1 arcs>"
# repr(g)  # donne "Graphe(2 sommets, 1 arcs)"
# ```
#
# 3. Coder la méthode `initialiser_avec_dict()` pour obtenir le comportement suivant
#
# ```python
# donnees = {
#     "nom": "example043",
#     "sommets": ['A', 'B', 'C', 'D'],
#     "arcs": [
#         ('D', 'C', 8), ('D', 'B', 6), ('B', 'D', 6),
#         ('A', 'C', 3), ('A', 'B', 2), ('A', 'D', 7),
#         ('C', 'A', 7), ('C', 'B', 9), ('D', 'A', 8),
#     ]
# }
#
# g = Graph():
# g.initialiser_avec_dict(donnees)
# str(g)  # donne "<Graphe: graphe_demo, 4 sommets, 9 arcs>"
# ```
#
# 4. Coder la méthode la méthode `rapport_textuel()` pour obtenir le comportement suivant
#
# ```python
# donnees = {
#     "nom": "example043",
#     "sommets": ['A', 'B', 'C', 'D'],
#     "arcs": [
#         ('D', 'C', 8), ('D', 'B', 6), ('B', 'D', 6), ('A', 'C', 3),
#         ('A', 'B', 2), ('A', 'D', 7), ('C', 'A', 7), ('C', 'B', 9),
#         ('D', 'A', 8),
#     ]
# }
#
# g = Graph():
# g.initialiser_avec_dict(donnees)
# print(g.rapport_textuel())
# ```
#
# le résultat attendu est
#
# ```none
# Rapport sur le graphe 'example043'
#
# - 4 sommets : A, B, C, D
# - 9 arcs : (D, C, 8), (D, B, 6), (B, D, 6), (A, C, 3), (A, B, 2), (A, D, 7), (C, A, 7), (C, B, 9), (D, A, 8)
#
# Tableau des distances minimales entre les sommets
#
# ... pas encore codé
#
# La plus grande longueur des plus courts chemins est
#
# ... pas encore codé
#
# ```
#
# 5. Coder `initialiser_avec_fichier()` pour obtenir le comportement suivant
#
# ```python
# g = Graph():
# g.initialiser_avec_fichier(".json")
# str(g)  # donne "<Graphe: graphe_demo, 4 sommets, 9 arcs>"
# ```
#
# 6. pour tester plus en profondeur votre code, ajouter une méthode dont l'objectif est de parcourir le graphe en partant d'un sommet donné et en renvoyant la liste des sommets parcourus

# %% [markdown]
# ## Les attendus de la séance 2
#
# 1. Coder la méthode `dijstra()`
# 2. Compléter le codage de la méthode `rapport_textuel()`
#
# ```python
# donnees = {
#     "nom": "example043",
#     "sommets": ['A', 'B', 'C', 'D'],
#     "arcs": [
#         ('D', 'C', 8), ('D', 'B', 6), ('B', 'D', 6), ('A', 'C', 3),
#         ('A', 'B', 2), ('A', 'D', 7), ('C', 'A', 7), ('C', 'B', 9),
#         ('D', 'A', 8),
#     ]
# }
#
# g = Graph():
# g.initialiser_avec_dict(donnees)
# print(g.rapport_textuel())
# ```
#
# le résultat attendu est
#
# ```none
# Rapport sur le graphe 'example043'
#
# - 4 sommets : A, B, C, D
# - 9 arcs : (D, C, 8), (D, B, 6), (B, D, 6), (A, C, 3), (A, B, 2), (A, D, 7), (C, A, 7), (C, B, 9), (D, A, 8)
#
# Tableau des distances minimales entre les sommets
#
#      A  B  C  D
#   A  0  2  3  7
#   B 14  0 14  6
#   C  7  9  0 14
#   D  8  6  8  0
#
# La plus grande longueur des plus courts chemins est 14
#   chemin 1 : B -> D -> C
#   chemin 2 : B -> D -> A
#   chemin 3 : C -> A -> D
# ```

# %% [markdown]
# ## Les attendus de la séance 3
#
# 1. Coder la méthode `rapport_html()`
#
#
# ```python
# donnees = {
#     "nom": "example043",
#     "sommets": ['A', 'B', 'C', 'D'],
#     "arcs": [
#         ('D', 'C', 8), ('D', 'B', 6), ('B', 'D', 6), ('A', 'C', 3),
#         ('A', 'B', 2), ('A', 'D', 7), ('C', 'A', 7), ('C', 'B', 9),
#         ('D', 'A', 8),
#     ]
# }
#
# g = Graph():
# g.initialiser_avec_dict(donnees)
# print(g.rapport_textuel())
# ```
#
# Le résultat attendu est présenté dans la copie d'écran ci-dessous. Les choix de mise en page sont laissés libre (police, taille et couleur des caractères ; ligne, couleur, legende du tableau, couleur et aspect des éléments graphique des graphes)
#
# <img src="data:image/png;base64,..."/>
